# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\juanj\OneDrive\Documentos\GitHub\CD\Projeto 01

# %%
dados2015=pd.read_table("PNAD DOM2015\\DOM2015csv\\DOM2015.csv", encoding="windows-1252", sep=",")

# %%
dados2015.shape
# Out:
# (151189, 81)

# %%
# SEPARANDO OS DOMICILIOS POR REGIOES
dados2015.shape
dados2015.loc[(dados2015.UF>10)&(dados2015.UF<20),"REGIAO"] = "Norte"
dados2015.loc[(dados2015.UF>20)&(dados2015.UF<30),"REGIAO"] = "Nordeste"
dados2015.loc[(dados2015.UF>40)&(dados2015.UF<44),"REGIAO"] = "Sul"
dados2015.loc[(dados2015.UF>30)&(dados2015.UF<35),"REGIAO"] = "Sudeste"
dados2015.loc[(dados2015.UF>49)&(dados2015.UF<54),"REGIAO"] = "Centro-Oeste"
dados2015.head(5)
# Out:
#    Unnamed: 0  V0101  UF  V0102  V0103  V0104  V0105  V0106  V0201  V0202  \
# 0           0   2015  11     15      1      1    1.0    1.0    1.0    4.0
# 1           1   2015  11     15      2      6    NaN    NaN    NaN    NaN
# 2           2   2015  11     15      3      1    1.0    1.0    1.0    4.0
# 3           3   2015  11     15      4      1    6.0    4.0    1.0    2.0
# 4           4   2015  11     15      5      1    2.0    2.0    1.0    2.0
#
#     ...     V4614  UPA   V4617  V4618  V4620   V4621  V4622  V4624     V9992  \
# 0   ...     800.0  191  110001      1    1.0   800.0    4.0    1.0  20161104
# 1   ...       NaN  191  110001      1    NaN     NaN    NaN    NaN  20161104
# 2   ...    1150.0  191  110001      1    1.0  1150.0    4.0    1.0  20161104
# 3   ...    4760.0  191  110001      1    6.0   793.0    4.0    2.0  20161104
# 4   ...    5800.0  191  110001      1    2.0  2900.0    6.0    2.0  20161104
#
#    REGIAO
# 0   Norte
# 1   Norte
# 2   Norte
# 3   Norte
# 4   Norte
#
# [5 rows x 82 columns]

# %%
# Tenho o intuito de analisar a renda da populucao brasileira nas diferentes regioes e simultaneamente analisar o acesso a
# celular e internet, e, com isso, procurar um mercado promissor (com boa renda e pouco acesso comparado)

# %%
#CRIANDO UM FILTRO PARA REGIÕES URBANAS E RURAIS

dados2015.loc[(dados2015.V4105>=1)&(dados2015.V4105<=3),"URBANIZACAO"] = "Urbana"
dados2015.loc[(dados2015.V4105>3)&(dados2015.V4105<=8),"URBANIZACAO"] = "Rural"

# %%
# CRIANDO UM FILTRO PARA RENDIMENTO DOMICILIAR

# dados2015.loc[(dados2015.V4614>=1)&(dados2015.V4614<=500),"RENDA"] = "Até R$500"
# dados2015.loc[(dados2015.V4614>500)&(dados2015.V4614<=1000),"RENDA"] = "Entre R$500 e R$1000"
# dados2015.loc[(dados2015.V4614>1000)&(dados2015.V4614<=2000),"RENDA"] = "Entre R$1.000 e R$2.000"
# dados2015.loc[(dados2015.V4614>2000)&(dados2015.V4614<=3000),"RENDA"] = "Entre R$2.000 e R$3.000"
# dados2015.loc[(dados2015.V4614>3000)&(dados2015.V4614<=5000),"RENDA"] = "Entre R$3.000 e R$5.000"
# dados2015.loc[(dados2015.V4614>5000)&(dados2015.V4614<=10000),"RENDA"] = "Entre R$5.000 e R$10.000"
# dados2015.loc[(dados2015.V4614>10000),"RENDA"] = "Maior que R$10.000"
dados2015 = dados2015.rename(columns = {"V4614":"RENDA"})

# %%
# CRIANDO UM FILTRO PARA RENDIMENTO MENSAL DOMICILIAR EM SALARIOS MINIMOS 

dados2015.loc[(dados2015.RENDA>=1)&(dados2015.RENDA<=(937*(1/2))),"SALARIOS MINIMOS"] = "1/2 salarios"
dados2015.loc[(dados2015.RENDA>(937*(1/2)))&(dados2015.RENDA<=937),"SALARIOS MINIMOS"] = "Entre 1/2 e 1 salario"
dados2015.loc[(dados2015.RENDA>937)&(dados2015.RENDA<=937*2),"SALARIOS MINIMOS"] = "Entre 1 e 2 salarios"
dados2015.loc[(dados2015.RENDA>937*2)&(dados2015.RENDA<=937*3),"SALARIOS MINIMOS"] = "Entre 2 e 3 salarios"
dados2015.loc[(dados2015.RENDA>937*3)&(dados2015.RENDA<=937*5),"SALARIOS MINIMOS"] = "Entre 3 e 5 salarios"
dados2015.loc[(dados2015.RENDA>937*5)&(dados2015.RENDA<=937*10),"SALARIOS MINIMOS"] = "Entre 5 e 10 salarios"
dados2015.loc[(dados2015.RENDA>937*10),"SALARIOS MINIMOS"] = "Mais que 10 salarios"

# %%
# CRIANDO UM FILTRO PARA AS PESSOAS QUE TEM ACESSO A INTERNET NO PROPRIO DOMICILIO

dados2015.loc[(dados2015.V02322 == 2),"ACESSO A INTERNET"] = "Sim"
dados2015.loc[(dados2015.V02322 == 4),"ACESSO A INTERNET"] = "Nao"

# %%
# CRIANDO UM FILTRO PARA AS PESSOAS QUE TEM ACESSO A CELULAR NO PROPRIO DOMICILIO

dados2015.loc[(dados2015.V0220 == 2),"ACESSO A CELULAR"] = "Sim"
dados2015.loc[(dados2015.V0220 == 4),"ACESSO A CELULAR"] = "Nao"

# %%
dados2015["ACESSO A CELULAR"].value_counts()
# Out:
# Sim    107849
# Nao      9752
# Name: ACESSO A CELULAR, dtype: int64

# %%
dados_interesse = dados2015.loc[:, ["REGIAO","URBANIZACAO","RENDA","SALARIOS MINIMOS","ACESSO A INTERNET","ACESSO A CELULAR"]]

# %%
dados_interesse
# Out:
#               REGIAO URBANIZACAO         RENDA       SALARIOS MINIMOS  \
# 0              Norte      Urbana  8.000000e+02  Entre 1/2 e 1 salario
# 1              Norte      Urbana           NaN                    NaN
# 2              Norte      Urbana  1.150000e+03   Entre 1 e 2 salarios
# 3              Norte      Urbana  4.760000e+03  Entre 5 e 10 salarios
# 4              Norte      Urbana  5.800000e+03  Entre 5 e 10 salarios
# 5              Norte      Urbana  1.990000e+03   Entre 2 e 3 salarios
# 6              Norte      Urbana  7.000000e+02  Entre 1/2 e 1 salario
# 7              Norte      Urbana  4.000000e+03   Entre 3 e 5 salarios
# 8              Norte      Urbana  4.090000e+03   Entre 3 e 5 salarios
# 9              Norte      Urbana           NaN                    NaN
# 10             Norte      Urbana  5.150000e+03  Entre 5 e 10 salarios
# 11             Norte      Urbana  2.500000e+03   Entre 2 e 3 salarios
# 12             Norte      Urbana           NaN                    NaN
# 13             Norte      Urbana  2.800000e+03   Entre 2 e 3 salarios
# 14             Norte      Urbana           NaN                    NaN
# 15             Norte      Urbana  2.000000e+03   Entre 2 e 3 salarios
# 16             Norte      Urbana  7.880000e+02  Entre 1/2 e 1 salario
# 17             Norte      Urbana  3.000000e+03   Entre 3 e 5 salarios
# 18             Norte      Urbana  7.188000e+03  Entre 5 e 10 salarios
# 19             Norte      Urbana  1.200000e+03   Entre 1 e 2 salarios
# 20             Norte      Urbana  2.800000e+03   Entre 2 e 3 salarios
# 21             Norte      Urbana  4.350000e+03   Entre 3 e 5 salarios
# 22             Norte      Urbana           NaN                    NaN
# 23             Norte      Urbana  8.000000e+03  Entre 5 e 10 salarios
# 24             Norte      Urbana           NaN                    NaN
# 25             Norte      Urbana           NaN                    NaN
# 26             Norte      Urbana  2.100000e+03   Entre 2 e 3 salarios
# 27             Norte      Urbana  1.330000e+04   Mais que 10 salarios
# 28             Norte      Urbana  7.000000e+03  Entre 5 e 10 salarios
# 29             Norte      Urbana  4.688000e+03  Entre 5 e 10 salarios
# ...              ...         ...           ...                    ...
# 151159  Centro-Oeste      Urbana  1.820000e+04   Mais que 10 salarios
# 151160  Centro-Oeste      Urbana           NaN                    NaN
# 151161  Centro-Oeste      Urbana  3.100000e+04   Mais que 10 salarios
# 151162  Centro-Oeste      Urbana           NaN                    NaN
# 151163  Centro-Oeste      Urbana  1.250000e+04   Mais que 10 salarios
# 151164  Centro-Oeste      Urbana  3.000000e+04   Mais que 10 salarios
# 151165  Centro-Oeste      Urbana  3.040000e+04   Mais que 10 salarios
# 151166  Centro-Oeste      Urbana           NaN                    NaN
# 151167  Centro-Oeste      Urbana  3.750000e+04   Mais que 10 salarios
# 151168  Centro-Oeste      Urbana  3.970000e+04   Mais que 10 salarios
# 151169  Centro-Oeste      Urbana  3.170000e+04   Mais que 10 salarios
# 151170  Centro-Oeste      Urbana  3.064000e+04   Mais que 10 salarios
# 151171  Centro-Oeste      Urbana  1.300000e+04   Mais que 10 salarios
# 151172  Centro-Oeste      Urbana  2.712000e+03   Entre 2 e 3 salarios
# 151173  Centro-Oeste      Urbana  2.630000e+03   Entre 2 e 3 salarios
# 151174  Centro-Oeste      Urbana           NaN                    NaN
# 151175  Centro-Oeste      Urbana  3.176000e+03   Entre 3 e 5 salarios
# 151176  Centro-Oeste      Urbana           NaN                    NaN
# 151177  Centro-Oeste      Urbana           NaN                    NaN
# 151178  Centro-Oeste      Urbana           NaN                    NaN
# 151179  Centro-Oeste      Urbana  1.100000e+03   Entre 1 e 2 salarios
# 151180  Centro-Oeste      Urbana  1.000000e+12   Mais que 10 salarios
# 151181  Centro-Oeste      Urbana  1.689000e+03   Entre 1 e 2 salarios
# 151182  Centro-Oeste      Urbana  3.100000e+03   Entre 3 e 5 salarios
# 151183  Centro-Oeste      Urbana           NaN                    NaN
# 151184  Centro-Oeste      Urbana  2.700000e+03   Entre 2 e 3 salarios
# 151185  Centro-Oeste      Urbana  5.000000e+02  Entre 1/2 e 1 salario
# 151186  Centro-Oeste      Urbana  2.388000e+03   Entre 2 e 3 salarios
# 151187  Centro-Oeste      Urbana  1.500000e+03   Entre 1 e 2 salarios
# 151188  Centro-Oeste      Urbana  1.296000e+03   Entre 1 e 2 salarios
#
#        ACESSO A INTERNET ACESSO A CELULAR
# 0                    Nao              Sim
# 1                    NaN              NaN
# 2                    Sim              Sim
# 3                    Sim              Sim
# 4                    Nao              Sim
# 5                    Sim              Nao
# 6                    Nao              Sim
# 7                    Nao              Sim
# 8                    Sim              Sim
# 9                    NaN              NaN
# 10                   Sim              Sim
# 11                   Sim              Sim
# 12                   NaN              NaN
# 13                   Sim              Sim
# 14                   NaN              NaN
# 15                   Sim              Sim
# 16                   Nao              Sim
# 17                   Sim              Sim
# 18                   Sim              Sim
# 19                   Sim              Sim
# 20                   Sim              Sim
# 21                   Nao              Sim
# 22                   NaN              NaN
# 23                   Sim              Sim
# 24                   NaN              NaN
# 25                   NaN              NaN
# 26                   Nao              Sim
# 27                   Sim              Sim
# 28                   Sim              Sim
# 29                   Sim              Sim
# ...                  ...              ...
# 151159               Sim              Sim
# 151160               NaN              NaN
# 151161               Sim              Sim
# 151162               NaN              NaN
# 151163               Sim              Sim
# 151164               Sim              Sim
# 151165               Sim              Sim
# 151166               NaN              NaN
# 151167               Sim              Sim
# 151168               Sim              Sim
# 151169               Sim              Sim
# 151170               Sim              Sim
# 151171               Sim              Sim
# 151172               Nao              Sim
# 151173               Sim              Sim
# 151174               NaN              NaN
# 151175               Sim              Sim
# 151176               NaN              NaN
# 151177               NaN              NaN
# 151178               NaN              NaN
# 151179               Nao              Sim
# 151180               Nao              Sim
# 151181               Nao              Sim
# 151182               Sim              Sim
# 151183               NaN              NaN
# 151184               Nao              Sim
# 151185               Nao              Sim
# 151186               Sim              Sim
# 151187               Nao              Sim
# 151188               Sim              Sim
#
# [151189 rows x 6 columns]

# %%
#(dados_interesse.RENDA).round(decimals=1)

# %%
! explorer .

# %%
dados_interesse.dropna(axis = 0)
#dados_interesse = dados_interesse[pd.notnull(dados_interesse["RENDA"])]
# Out:
#               REGIAO URBANIZACAO         RENDA       SALARIOS MINIMOS  \
# 0              Norte      Urbana  8.000000e+02  Entre 1/2 e 1 salario
# 2              Norte      Urbana  1.150000e+03   Entre 1 e 2 salarios
# 3              Norte      Urbana  4.760000e+03  Entre 5 e 10 salarios
# 4              Norte      Urbana  5.800000e+03  Entre 5 e 10 salarios
# 5              Norte      Urbana  1.990000e+03   Entre 2 e 3 salarios
# 6              Norte      Urbana  7.000000e+02  Entre 1/2 e 1 salario
# 7              Norte      Urbana  4.000000e+03   Entre 3 e 5 salarios
# 8              Norte      Urbana  4.090000e+03   Entre 3 e 5 salarios
# 10             Norte      Urbana  5.150000e+03  Entre 5 e 10 salarios
# 11             Norte      Urbana  2.500000e+03   Entre 2 e 3 salarios
# 13             Norte      Urbana  2.800000e+03   Entre 2 e 3 salarios
# 15             Norte      Urbana  2.000000e+03   Entre 2 e 3 salarios
# 16             Norte      Urbana  7.880000e+02  Entre 1/2 e 1 salario
# 17             Norte      Urbana  3.000000e+03   Entre 3 e 5 salarios
# 18             Norte      Urbana  7.188000e+03  Entre 5 e 10 salarios
# 19             Norte      Urbana  1.200000e+03   Entre 1 e 2 salarios
# 20             Norte      Urbana  2.800000e+03   Entre 2 e 3 salarios
# 21             Norte      Urbana  4.350000e+03   Entre 3 e 5 salarios
# 23             Norte      Urbana  8.000000e+03  Entre 5 e 10 salarios
# 26             Norte      Urbana  2.100000e+03   Entre 2 e 3 salarios
# 27             Norte      Urbana  1.330000e+04   Mais que 10 salarios
# 28             Norte      Urbana  7.000000e+03  Entre 5 e 10 salarios
# 29             Norte      Urbana  4.688000e+03  Entre 5 e 10 salarios
# 30             Norte      Urbana  3.818000e+03   Entre 3 e 5 salarios
# 31             Norte      Urbana  9.000000e+03  Entre 5 e 10 salarios
# 32             Norte      Urbana  2.200000e+03   Entre 2 e 3 salarios
# 33             Norte      Urbana  7.000000e+02  Entre 1/2 e 1 salario
# 35             Norte      Urbana  7.880000e+02  Entre 1/2 e 1 salario
# 36             Norte      Urbana  1.800000e+02           1/2 salarios
# 37             Norte      Urbana  1.788000e+03   Entre 1 e 2 salarios
# ...              ...         ...           ...                    ...
# 151147  Centro-Oeste      Urbana  1.109000e+03   Entre 1 e 2 salarios
# 151148  Centro-Oeste      Urbana  8.500000e+02  Entre 1/2 e 1 salario
# 151150  Centro-Oeste      Urbana  5.709000e+03  Entre 5 e 10 salarios
# 151151  Centro-Oeste      Urbana  1.066000e+03   Entre 1 e 2 salarios
# 151153  Centro-Oeste      Urbana  2.200000e+03   Entre 2 e 3 salarios
# 151155  Centro-Oeste      Urbana  8.700000e+03  Entre 5 e 10 salarios
# 151156  Centro-Oeste      Urbana  5.000000e+03  Entre 5 e 10 salarios
# 151158  Centro-Oeste      Urbana  1.550000e+04   Mais que 10 salarios
# 151159  Centro-Oeste      Urbana  1.820000e+04   Mais que 10 salarios
# 151161  Centro-Oeste      Urbana  3.100000e+04   Mais que 10 salarios
# 151163  Centro-Oeste      Urbana  1.250000e+04   Mais que 10 salarios
# 151164  Centro-Oeste      Urbana  3.000000e+04   Mais que 10 salarios
# 151165  Centro-Oeste      Urbana  3.040000e+04   Mais que 10 salarios
# 151167  Centro-Oeste      Urbana  3.750000e+04   Mais que 10 salarios
# 151168  Centro-Oeste      Urbana  3.970000e+04   Mais que 10 salarios
# 151169  Centro-Oeste      Urbana  3.170000e+04   Mais que 10 salarios
# 151170  Centro-Oeste      Urbana  3.064000e+04   Mais que 10 salarios
# 151171  Centro-Oeste      Urbana  1.300000e+04   Mais que 10 salarios
# 151172  Centro-Oeste      Urbana  2.712000e+03   Entre 2 e 3 salarios
# 151173  Centro-Oeste      Urbana  2.630000e+03   Entre 2 e 3 salarios
# 151175  Centro-Oeste      Urbana  3.176000e+03   Entre 3 e 5 salarios
# 151179  Centro-Oeste      Urbana  1.100000e+03   Entre 1 e 2 salarios
# 151180  Centro-Oeste      Urbana  1.000000e+12   Mais que 10 salarios
# 151181  Centro-Oeste      Urbana  1.689000e+03   Entre 1 e 2 salarios
# 151182  Centro-Oeste      Urbana  3.100000e+03   Entre 3 e 5 salarios
# 151184  Centro-Oeste      Urbana  2.700000e+03   Entre 2 e 3 salarios
# 151185  Centro-Oeste      Urbana  5.000000e+02  Entre 1/2 e 1 salario
# 151186  Centro-Oeste      Urbana  2.388000e+03   Entre 2 e 3 salarios
# 151187  Centro-Oeste      Urbana  1.500000e+03   Entre 1 e 2 salarios
# 151188  Centro-Oeste      Urbana  1.296000e+03   Entre 1 e 2 salarios
#
#        ACESSO A INTERNET ACESSO A CELULAR
# 0                    Nao              Sim
# 2                    Sim              Sim
# 3                    Sim              Sim
# 4                    Nao              Sim
# 5                    Sim              Nao
# 6                    Nao              Sim
# 7                    Nao              Sim
# 8                    Sim              Sim
# 10                   Sim              Sim
# 11                   Sim              Sim
# 13                   Sim              Sim
# 15                   Sim              Sim
# 16                   Nao              Sim
# 17                   Sim              Sim
# 18                   Sim              Sim
# 19                   Sim              Sim
# 20                   Sim              Sim
# 21                   Nao              Sim
# 23                   Sim              Sim
# 26                   Nao              Sim
# 27                   Sim              Sim
# 28                   Sim              Sim
# 29                   Sim              Sim
# 30                   Nao              Nao
# 31                   Sim              Sim
# 32                   Sim              Sim
# 33                   Sim              Sim
# 35                   Nao              Sim
# 36                   Nao              Sim
# 37                   Sim              Sim
# ...                  ...              ...
# 151147               Sim              Sim
# 151148               Sim              Sim
# 151150               Sim              Sim
# 151151               Sim              Sim
# 151153               Sim              Sim
# 151155               Nao              Sim
# 151156               Sim              Sim
# 151158               Sim              Sim
# 151159               Sim              Sim
# 151161               Sim              Sim
# 151163               Sim              Sim
# 151164               Sim              Sim
# 151165               Sim              Sim
# 151167               Sim              Sim
# 151168               Sim              Sim
# 151169               Sim              Sim
# 151170               Sim              Sim
# 151171               Sim              Sim
# 151172               Nao              Sim
# 151173               Sim              Sim
# 151175               Sim              Sim
# 151179               Nao              Sim
# 151180               Nao              Sim
# 151181               Nao              Sim
# 151182               Sim              Sim
# 151184               Nao              Sim
# 151185               Nao              Sim
# 151186               Sim              Sim
# 151187               Nao              Sim
# 151188               Sim              Sim
#
# [103484 rows x 6 columns]

# %%
# Dados filtrados, tirados os valores invalidos

# %%
dados_interesse.RENDA.describe()
# Out:
# count    1.179390e+05
# mean     1.961184e+10
# std      1.386628e+11
# min      0.000000e+00
# 25%      1.100000e+03
# 50%      2.000000e+03
# 75%      3.688000e+03
# max      1.000000e+12
# Name: RENDA, dtype: float64

# %%
#Existem valores muito altos de renda que nao descrevem a população em geral, entao, resolvi excluir esses valores 
#da minha análise

# %%
quantils=dados_interesse.RENDA.quantile(np.arange(0,1,.1))
quantils.plot(kind="box",grid=True)

# %%
quantils.describe()
# Out:
# count      10.000000
# mean     2367.200000
# std      2070.539854
# min         0.000000
# 25%      1033.000000
# 50%      1794.000000
# 75%      3007.000000
# max      7076.000000
# Name: RENDA, dtype: float64

# %%
# retirado a parte que nao representa a populacao, tem-se uma melhor analise de dados

# %%
# Separando faixas iguais de renda em salarios minimos

faixa = np.arange(0,10000,937)
sal_min = pd.cut(dados_interesse.RENDA,faixa)
#sal_min.value_counts()
plot = dados_interesse.RENDA.plot.hist(bins=faixa, normed = True,color="darkslateblue")
plt.xlabel("Renda [Reais]")
plt.ylabel("Densidade")
plt.grid(True)

# %%
#Esse grafico deixa claro onde está as rendas que representam melhor a população entre (0 e 5000), a partir disso, a porcentagem 
# da populacao representada é infima

# %%
sal_min.value_counts()
sal_reg=pd.crosstab(dados_interesse["REGIAO"],sal_min,normalize = True)
b=sal_reg.sum().sum()
sal_reg*100/b
# Out:
# RENDA          (0, 937]  (937, 1874]  (1874, 2811]  (2811, 3748]  \
# REGIAO
# Centro-Oeste   1.622373     3.063453      2.608158      1.412237
# Nordeste      10.500618    10.592295      5.456325      2.258962
# Norte          4.273795     5.519159      2.983107      1.436959
# Sudeste        3.609394     6.159868      4.692007      2.683354
# Sul            2.047796     4.527194      4.078080      2.669963
#
# RENDA         (3748, 4685]  (4685, 5622]  (5622, 6559]  (6559, 7496]  \
# REGIAO
# Centro-Oeste      1.072311      0.666461      0.430573      0.291512
# Nordeste          1.291718      0.781829      0.520190      0.298723
# Norte             0.850845      0.539761      0.349197      0.221467
# Sudeste           1.614133      1.044499      0.636588      0.437783
# Sul               1.845900      1.188710      0.760198      0.454265
#
# RENDA         (7496, 8433]  (8433, 9370]
# REGIAO
# Centro-Oeste      0.284302      0.167903
# Nordeste          0.257520      0.188504
# Norte             0.191595      0.125670
# Sudeste           0.374948      0.244129
# Sul               0.402761      0.270911

# %%
#Nordeste e Norte

# %%
sal_reg.plot(kind="bar", figsize=(20, 10))
plt.ylabel("Porcentagem da População")

# %%
# fig,ax = plt.figure(figsize=(5,12))
# #plt.subplot()

# for i in range(0,5):
#     plt.subplot(1,2,i+1)
#     sal_reg[col[i]].plot(kind="bar")

# %%
#fig,ax = plt.subplots()
#sal_reg[:1].plot(kind="bar")
for i in range(5):
    sal_reg[i:i+1].plot(kind="bar",grid = True)

# %%
# grande parte da regiao nordeste e norte vive com menos de 3 salarios minimos, mas representam grande parte da populacao
# regiao sul, centro-oeste e sudeste sao regioes mais ricas
# Out:
# count    1.179390e+05
# mean     1.961184e+10
# std      1.386628e+11
# min      0.000000e+00
# 25%      1.100000e+03
# 50%      2.000000e+03
# 75%      3.688000e+03
# max      1.000000e+12
# Name: RENDA, dtype: float64

# %%
sal_min.value_counts()
sal_net=pd.crosstab(dados_interesse["ACESSO A INTERNET"],sal_min,normalize = True)
# ronaldo=pd.crosstab(sal_net,dados_interesse["REGIAO"])
b=sal_net.sum().sum()
sal_net*100/b
# Out:
# RENDA               (0, 937]  (937, 1874]  (1874, 2811]  (2811, 3748]  \
# ACESSO A INTERNET
# Nao                15.114310    16.180098      7.706255      2.943342
# Sim                 5.664875    12.940397     12.411184      8.052314
#
# RENDA              (3748, 4685]  (4685, 5622]  (5622, 6559]  (6559, 7496]  \
# ACESSO A INTERNET
# Nao                    1.311527      0.602842      0.286235      0.179472
# Sim                    5.746788      3.945625      2.600965      1.648382
#
# RENDA              (7496, 8433]  (8433, 9370]
# ACESSO A INTERNET
# Nao                    0.127011      0.075470
# Sim                    1.494680      0.968229

# %%
sal_net.sum()
dados_interesse()
# Out:
# RENDA
# (0, 937]        0.207792
# (937, 1874]     0.291205
# (1874, 2811]    0.201174
# (2811, 3748]    0.109957
# (3748, 4685]    0.070583
# (4685, 5622]    0.045485
# (5622, 6559]    0.028872
# (6559, 7496]    0.018279
# (7496, 8433]    0.016217
# (8433, 9370]    0.010437
# dtype: float64

# %%
#existe grande parte da populacao que ainda nao tem acesso a internet e tem uma renda razoavel
# Out:
# count      10.000000
# mean     2367.200000
# std      2070.539854
# min         0.000000
# 25%      1033.000000
# 50%      1794.000000
# 75%      3007.000000
# max      7076.000000
# Name: RENDA, dtype: float64

# %%
sal_cel=pd.crosstab(sal_min,dados_interesse["ACESSO A CELULAR"],normalize = True)
# ronaldo=pd.crosstab(sal_net,dados_interesse["REGIAO"])
# b=sal_cel.sum().sum()
# sal_cel*100/b
sal_cel
# Out:
# ACESSO A CELULAR       Nao       Sim
# RENDA
# (0, 937]          0.043359  0.164433
# (937, 1874]       0.029765  0.261440
# (1874, 2811]      0.008817  0.192357
# (2811, 3748]      0.002872  0.107085
# (3748, 4685]      0.001068  0.069516
# (4685, 5622]      0.000534  0.044951
# (5622, 6559]      0.000267  0.028605
# (6559, 7496]      0.000221  0.018058
# (7496, 8433]      0.000110  0.016106
# (8433, 9370]      0.000074  0.010363

# %%
# Out:
# count    1.179390e+05
# mean     1.961184e+10
# std      1.386628e+11
# min      0.000000e+00
# 25%      1.100000e+03
# 50%      2.000000e+03
# 75%      3.688000e+03
# max      1.000000e+12
# Name: RENDA, dtype: float64

# %%
dados_interesse.to_csv("filtrado.csv")
